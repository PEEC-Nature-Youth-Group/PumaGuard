# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_dimensions = (512, 512) # height, width
with_augmentation = False
batch_size = 16
model_version = "XCeption"
model_file = f'/content/drive/MyDrive/lion_no_lion/model_weights_Adis_{model_version}_{image_dimensions[0]}_{image_dimensions[1]}.keras'
history_file = f'/content/drive/MyDrive/lion_no_lion/model_history_Adis_{model_version}_{image_dimensions[0]}_{image_dimensions[1]}.pickle'
lion_directories = [
    '/content/drive/MyDrive/lion_no_lion/lion',
    '/content/drive/MyDrive/lion_no_lion/cougar',
]
no_lion_directories = [
    '/content/drive/MyDrive/lion_no_lion/no_lion',
    '/content/drive/MyDrive/lion_no_lion/nocougar',
]

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
  tf.config.experimental_connect_to_cluster(tpu)
  tf.tpu.experimental.initialize_tpu_system(tpu)
  distribution_strategy = tf.distribute.TPUStrategy(tpu)
  print(f'Running on a TPU w/{tpu.num_accelerators()["TPU"]} cores')
except ValueError:
  print("WARNING: Not connected to a TPU runtime; WIll try GPU")
  if tf.config.list_physical_devices('GPU'):
    distribution_strategy = tf.distribute.MirroredStrategy()
    print(f'Running on {len(tf.config.list_physical_devices("GPU"))} GPUs')
  else:
    print('WARNING: Not connected to TPU or GPU runtime; Will use CPU context')
    distribution_strategy = tf.distribute.get_strategy()
# Out:
# Tensorflow version 2.15.0
# Running on a TPU w/8 cores

# %%
import os

with distribution_strategy.scope():
    try:
        os.stat(model_file)
        print(f'Loading model from file {model_file}')
        model = tf.keras.models.load_model(model_file)
        print('Loaded model from file')
    except FileNotFoundError:
        if model_version == "XCeption":
            print('Creating new XCeption model')
            base_model = tf.keras.applications.Xception(
                weights='imagenet',
                include_top=False,
                input_shape=(*image_dimensions, 3),
            )

            print(f'Number of layers in the base model: {len(base_model.layers)}')
            print(f'Shape of the output layer:          {base_model.layers[-1].output_shape}')

            base_model.trainable = False

            input_layers = []
            if with_augmentation:
                input_layers = [
                    tf.keras.layers.RandomFlip(),
                    tf.keras.layers.RandomRotation(0.01),
                    tf.keras.layers.RandomZoom(0.05),
                    tf.keras.layers.RandomBrightness((-0.1, 0.1)),
                    tf.keras.layers.RandomContrast(0.1),
                    # tf.keras.layers.RandomCrop(200, 200),
                    # tf.keras.layers.Rescaling(1./255),
                ]

            model = tf.keras.Sequential([
                *input_layers,
                base_model,
                tf.keras.layers.GlobalAveragePooling2D(),
                tf.keras.layers.Dense(1, activation='sigmoid'),
            ])
        else:
            raise Exception(f'unknonw model version {model_version}')

        model.build(input_shape=(None, *image_dimensions, 3))
# Out:
# Creating new XCeption model
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Number of layers in the base model: 132
# Shape of the output layer:          (None, 16, 16, 2048)

# %%
with distribution_strategy.scope():
    model.compile(
        optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=5e-5),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 16, 16, 2048)      20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 20863529 (79.59 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
import pickle

class StoreHistory(tf.keras.callbacks.Callback):
    def __init__(self):
        self.history = {}
        self.number_epochs = 0
        try:
            with open(history_file, 'rb') as f:
                self.history = pickle.load(f)
                self.number_epochs = len(self.history['loss'])
                print(f'Loaded history of {self.number_epochs} previous epochs')
                print(f'Epoch {self.number_epochs}: '
                      f'loss: {self.history["loss"][-1]:.4f} - '
                      f'accuracy: {self.history["accuracy"][-1]:.4f} - '
                      f'val_loss: {self.history["val_loss"][-1]:.4f} - '
                      f'val_accuracy: {self.history["val_accuracy"][-1]:.4f}')
        except FileNotFoundError:
            print('Initialized new history')
            pass

    def on_train_begin(self, logs=None):
        if not 'loss' in self.history:
            self.history['loss'] = []
        self.number_epochs = len(self.history['loss'])
        print(f'Starting new training with {self.number_epochs} previous epochs')

    def on_epoch_end(self, epoch, logs=None):
        if not 'batch_size' in self.history:
            self.history['batch_size'] = []
        self.history['batch_size'].append(batch_size)
        for key in logs:
          if not key in self.history:
              self.history[key] = []
          self.history[key].append(logs[key])
        with open(history_file, 'wb') as f:
            pickle.dump(self.history, f)
            print(f'Epoch {epoch + self.number_epochs + 1} history pickled and saved to file')

full_history = StoreHistory()

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_file,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    verbose=1,
)
# Out:
# Initialized new history

# %%
import glob
import shutil

lion_images = []
for lion in lion_directories:
    lion_images += glob.glob(os.path.join(lion, '*JPG'))
no_lion_images = []
for no_lion in no_lion_directories:
    no_lion_images += glob.glob(os.path.join(no_lion, '*JPG'))

print(f'Found {len(lion_images)} images tagged as `lion`')
print(f'Found {len(no_lion_images)} images tagges as `no-lion`')
print(f'In total {len(lion_images) + len(no_lion_images)} images')

shutil.rmtree('data', ignore_errors=True)
os.makedirs('data/lion')
os.makedirs('data/no_lion')

for image in lion_images:
    shutil.copy(image, 'data/lion')
for image in no_lion_images:
    shutil.copy(image, 'data/no_lion')

print('Copied all images')
# Out:
# Found 684 images tagged as `lion`
# Found 618 images tagges as `no-lion`
# In total 1302 images
# Copied all images

# %%
training_dataset, validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'data',
    batch_size=batch_size,
    validation_split=0.2,
    subset='both',
    seed=1042,
    shuffle=True,
    image_size=image_dimensions,
    color_mode='rgb',
)
# Out:
# Found 1281 files belonging to 2 classes.
# Using 1025 files for training.
# Using 256 files for validation.

# %%
from datetime import datetime

start_time = datetime.now()
print(start_time)
history = model.fit(
    training_dataset,
    epochs=300,
    validation_data=validation_dataset,
    callbacks=[
        tf.keras.callbacks.TensorBoard(log_dir='/content/drive/MyDrive/lion_no_lion/logs'),
        checkpoint,
        full_history,
    ]
)
end_time = datetime.now()
print(end_time)
print(f'This run took {(end_time - start_time).total_seconds()} seconds')
# Out:
# 2024-05-31 21:30:19.022409
# Starting new training with 0 previous epochs
# Epoch 1/300
#  6/65 [=>............................] - ETA: 4s - loss: 2.6623 - accuracy: 0.5000
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0634s vs `on_train_batch_end` time: 0.0943s). Check your callbacks.
# 65/65 [==============================] - ETA: 0s - loss: 2.5889 - accuracy: 0.5054
# Epoch 1: val_loss improved from inf to 2.22551, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 1 history pickled and saved to file
# 65/65 [==============================] - 30s 239ms/step - loss: 2.5889 - accuracy: 0.5054 - val_loss: 2.2255 - val_accuracy: 0.4961
# Epoch 2/300
# 64/65 [============================>.] - ETA: 0s - loss: 1.9081 - accuracy: 0.5410
# Epoch 2: val_loss improved from 2.22551 to 1.61592, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 2 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 1.9063 - accuracy: 0.5415 - val_loss: 1.6159 - val_accuracy: 0.5312
# Epoch 3/300
# 65/65 [==============================] - ETA: 0s - loss: 1.4585 - accuracy: 0.5824
# Epoch 3: val_loss improved from 1.61592 to 1.28597, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 3 history pickled and saved to file
# 65/65 [==============================] - 7s 106ms/step - loss: 1.4585 - accuracy: 0.5824 - val_loss: 1.2860 - val_accuracy: 0.5742
# Epoch 4/300
# 65/65 [==============================] - ETA: 0s - loss: 1.2243 - accuracy: 0.6244
# Epoch 4: val_loss improved from 1.28597 to 1.14041, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 4 history pickled and saved to file
# 65/65 [==============================] - 6s 95ms/step - loss: 1.2243 - accuracy: 0.6244 - val_loss: 1.1404 - val_accuracy: 0.6406
# Epoch 5/300
# 65/65 [==============================] - ETA: 0s - loss: 1.1191 - accuracy: 0.6585
# Epoch 5: val_loss improved from 1.14041 to 1.05006, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 5 history pickled and saved to file
# 65/65 [==============================] - 7s 100ms/step - loss: 1.1191 - accuracy: 0.6585 - val_loss: 1.0501 - val_accuracy: 0.6953
# Epoch 6/300
# 65/65 [==============================] - ETA: 0s - loss: 1.0548 - accuracy: 0.6761
# Epoch 6: val_loss improved from 1.05006 to 1.00176, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 6 history pickled and saved to file
# 65/65 [==============================] - 7s 96ms/step - loss: 1.0548 - accuracy: 0.6761 - val_loss: 1.0018 - val_accuracy: 0.7070
# Epoch 7/300
# 65/65 [==============================] - ETA: 0s - loss: 1.0058 - accuracy: 0.6878
# Epoch 7: val_loss improved from 1.00176 to 0.96368, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 7 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 1.0058 - accuracy: 0.6878 - val_loss: 0.9637 - val_accuracy: 0.7266
# Epoch 8/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.9585 - accuracy: 0.6924
# Epoch 8: val_loss improved from 0.96368 to 0.94201, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 8 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.9576 - accuracy: 0.6927 - val_loss: 0.9420 - val_accuracy: 0.7148
# Epoch 9/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.9296 - accuracy: 0.6982
# Epoch 9: val_loss improved from 0.94201 to 0.90283, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 9 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.9309 - accuracy: 0.6976 - val_loss: 0.9028 - val_accuracy: 0.7188
# Epoch 10/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.9029 - accuracy: 0.6943
# Epoch 10: val_loss improved from 0.90283 to 0.87983, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 10 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.9022 - accuracy: 0.6946 - val_loss: 0.8798 - val_accuracy: 0.7148
# Epoch 11/300
# 65/65 [==============================] - ETA: 0s - loss: 0.8728 - accuracy: 0.6956
# Epoch 11: val_loss improved from 0.87983 to 0.86967, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 11 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.8728 - accuracy: 0.6956 - val_loss: 0.8697 - val_accuracy: 0.7031
# Epoch 12/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.8548 - accuracy: 0.7002
# Epoch 12: val_loss improved from 0.86967 to 0.85175, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 12 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.8541 - accuracy: 0.7005 - val_loss: 0.8518 - val_accuracy: 0.7031
# Epoch 13/300
# 65/65 [==============================] - ETA: 0s - loss: 0.8299 - accuracy: 0.7073
# Epoch 13: val_loss improved from 0.85175 to 0.84417, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 13 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.8299 - accuracy: 0.7073 - val_loss: 0.8442 - val_accuracy: 0.6953
# Epoch 14/300
# 65/65 [==============================] - ETA: 0s - loss: 0.8107 - accuracy: 0.7034
# Epoch 14: val_loss improved from 0.84417 to 0.81550, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 14 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.8107 - accuracy: 0.7034 - val_loss: 0.8155 - val_accuracy: 0.7109
# Epoch 15/300
# 65/65 [==============================] - ETA: 0s - loss: 0.7963 - accuracy: 0.7063
# Epoch 15: val_loss improved from 0.81550 to 0.80798, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 15 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.7963 - accuracy: 0.7063 - val_loss: 0.8080 - val_accuracy: 0.6992
# Epoch 16/300
# 65/65 [==============================] - ETA: 0s - loss: 0.7804 - accuracy: 0.7151
# Epoch 16: val_loss improved from 0.80798 to 0.79811, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 16 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.7804 - accuracy: 0.7151 - val_loss: 0.7981 - val_accuracy: 0.6914
# Epoch 17/300
# 65/65 [==============================] - ETA: 0s - loss: 0.7628 - accuracy: 0.7210
# Epoch 17: val_loss improved from 0.79811 to 0.78151, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 17 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 0.7628 - accuracy: 0.7210 - val_loss: 0.7815 - val_accuracy: 0.6953
# Epoch 18/300
# 65/65 [==============================] - ETA: 0s - loss: 0.7496 - accuracy: 0.7229
# Epoch 18: val_loss improved from 0.78151 to 0.78036, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 18 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.7496 - accuracy: 0.7229 - val_loss: 0.7804 - val_accuracy: 0.7109
# Epoch 19/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.7306 - accuracy: 0.7207
# Epoch 19: val_loss improved from 0.78036 to 0.75990, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 19 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.7353 - accuracy: 0.7200 - val_loss: 0.7599 - val_accuracy: 0.7109
# Epoch 20/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.7201 - accuracy: 0.7266
# Epoch 20: val_loss improved from 0.75990 to 0.75625, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 20 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.7194 - accuracy: 0.7268 - val_loss: 0.7562 - val_accuracy: 0.7109
# Epoch 21/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.7041 - accuracy: 0.7324
# Epoch 21: val_loss improved from 0.75625 to 0.74659, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 21 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.7035 - accuracy: 0.7327 - val_loss: 0.7466 - val_accuracy: 0.7070
# Epoch 22/300
# 65/65 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.7366
# Epoch 22: val_loss improved from 0.74659 to 0.72525, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 22 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.6937 - accuracy: 0.7366 - val_loss: 0.7253 - val_accuracy: 0.7148
# Epoch 23/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.6765 - accuracy: 0.7393
# Epoch 23: val_loss improved from 0.72525 to 0.71038, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 23 history pickled and saved to file
# 65/65 [==============================] - 7s 101ms/step - loss: 0.6760 - accuracy: 0.7395 - val_loss: 0.7104 - val_accuracy: 0.7188
# Epoch 24/300
# 65/65 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.7356
# Epoch 24: val_loss improved from 0.71038 to 0.70584, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 24 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.6662 - accuracy: 0.7356 - val_loss: 0.7058 - val_accuracy: 0.7227
# Epoch 25/300
# 65/65 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.7424
# Epoch 25: val_loss improved from 0.70584 to 0.69685, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 25 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.6490 - accuracy: 0.7424 - val_loss: 0.6969 - val_accuracy: 0.7266
# Epoch 26/300
# 65/65 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.7512
# Epoch 26: val_loss improved from 0.69685 to 0.68970, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 26 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.6413 - accuracy: 0.7512 - val_loss: 0.6897 - val_accuracy: 0.7188
# Epoch 27/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.6302 - accuracy: 0.7471
# Epoch 27: val_loss improved from 0.68970 to 0.67923, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 27 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.6296 - accuracy: 0.7473 - val_loss: 0.6792 - val_accuracy: 0.7227
# Epoch 28/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.6175 - accuracy: 0.7559
# Epoch 28: val_loss did not improve from 0.67923
# Epoch 28 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.6181 - accuracy: 0.7551 - val_loss: 0.6941 - val_accuracy: 0.7070
# Epoch 29/300
# 65/65 [==============================] - ETA: 0s - loss: 0.6071 - accuracy: 0.7561
# Epoch 29: val_loss improved from 0.67923 to 0.66259, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 29 history pickled and saved to file
# 65/65 [==============================] - 7s 106ms/step - loss: 0.6071 - accuracy: 0.7561 - val_loss: 0.6626 - val_accuracy: 0.7188
# Epoch 30/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7571
# Epoch 30: val_loss improved from 0.66259 to 0.66060, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 30 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.5964 - accuracy: 0.7571 - val_loss: 0.6606 - val_accuracy: 0.7227
# Epoch 31/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5883 - accuracy: 0.7659
# Epoch 31: val_loss improved from 0.66060 to 0.66008, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 31 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.5883 - accuracy: 0.7659 - val_loss: 0.6601 - val_accuracy: 0.7148
# Epoch 32/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.7668
# Epoch 32: val_loss improved from 0.66008 to 0.63607, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 32 history pickled and saved to file
# 65/65 [==============================] - 7s 106ms/step - loss: 0.5772 - accuracy: 0.7668 - val_loss: 0.6361 - val_accuracy: 0.7266
# Epoch 33/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5730 - accuracy: 0.7678
# Epoch 33: val_loss improved from 0.63607 to 0.62509, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 33 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.5730 - accuracy: 0.7678 - val_loss: 0.6251 - val_accuracy: 0.7305
# Epoch 34/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.5617 - accuracy: 0.7676
# Epoch 34: val_loss did not improve from 0.62509
# Epoch 34 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.5611 - accuracy: 0.7678 - val_loss: 0.6264 - val_accuracy: 0.7305
# Epoch 35/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.5525 - accuracy: 0.7744
# Epoch 35: val_loss improved from 0.62509 to 0.62412, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 35 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.5540 - accuracy: 0.7737 - val_loss: 0.6241 - val_accuracy: 0.7305
# Epoch 36/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.5473 - accuracy: 0.7734
# Epoch 36: val_loss improved from 0.62412 to 0.62194, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 36 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.5474 - accuracy: 0.7737 - val_loss: 0.6219 - val_accuracy: 0.7344
# Epoch 37/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7815
# Epoch 37: val_loss improved from 0.62194 to 0.59987, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 37 history pickled and saved to file
# 65/65 [==============================] - 6s 95ms/step - loss: 0.5385 - accuracy: 0.7815 - val_loss: 0.5999 - val_accuracy: 0.7383
# Epoch 38/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7803
# Epoch 38: val_loss did not improve from 0.59987
# Epoch 38 history pickled and saved to file
# 65/65 [==============================] - 5s 80ms/step - loss: 0.5344 - accuracy: 0.7805 - val_loss: 0.6223 - val_accuracy: 0.7227
# Epoch 39/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5236 - accuracy: 0.7795
# Epoch 39: val_loss improved from 0.59987 to 0.59374, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 39 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.5236 - accuracy: 0.7795 - val_loss: 0.5937 - val_accuracy: 0.7422
# Epoch 40/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.7834
# Epoch 40: val_loss improved from 0.59374 to 0.59123, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 40 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.5163 - accuracy: 0.7834 - val_loss: 0.5912 - val_accuracy: 0.7383
# Epoch 41/300
# 65/65 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.7863
# Epoch 41: val_loss improved from 0.59123 to 0.57980, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 41 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.5088 - accuracy: 0.7863 - val_loss: 0.5798 - val_accuracy: 0.7422
# Epoch 42/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.5038 - accuracy: 0.7920
# Epoch 42: val_loss improved from 0.57980 to 0.57776, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 42 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.5034 - accuracy: 0.7922 - val_loss: 0.5778 - val_accuracy: 0.7422
# Epoch 43/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7891
# Epoch 43: val_loss improved from 0.57776 to 0.57770, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 43 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.4955 - accuracy: 0.7893 - val_loss: 0.5777 - val_accuracy: 0.7383
# Epoch 44/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4910 - accuracy: 0.7893
# Epoch 44: val_loss improved from 0.57770 to 0.57124, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 44 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.4910 - accuracy: 0.7893 - val_loss: 0.5712 - val_accuracy: 0.7383
# Epoch 45/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7988
# Epoch 45: val_loss did not improve from 0.57124
# Epoch 45 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4849 - accuracy: 0.7990 - val_loss: 0.5791 - val_accuracy: 0.7344
# Epoch 46/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.8029
# Epoch 46: val_loss improved from 0.57124 to 0.56418, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 46 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.4797 - accuracy: 0.8029 - val_loss: 0.5642 - val_accuracy: 0.7383
# Epoch 47/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4725 - accuracy: 0.8057
# Epoch 47: val_loss improved from 0.56418 to 0.55194, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 47 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 0.4725 - accuracy: 0.8059 - val_loss: 0.5519 - val_accuracy: 0.7422
# Epoch 48/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.8059
# Epoch 48: val_loss did not improve from 0.55194
# Epoch 48 history pickled and saved to file
# 65/65 [==============================] - 5s 70ms/step - loss: 0.4713 - accuracy: 0.8059 - val_loss: 0.5552 - val_accuracy: 0.7422
# Epoch 49/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.8117
# Epoch 49: val_loss did not improve from 0.55194
# Epoch 49 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4653 - accuracy: 0.8117 - val_loss: 0.5535 - val_accuracy: 0.7422
# Epoch 50/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4597 - accuracy: 0.8117
# Epoch 50: val_loss improved from 0.55194 to 0.54625, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 50 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.4597 - accuracy: 0.8117 - val_loss: 0.5462 - val_accuracy: 0.7461
# Epoch 51/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4552 - accuracy: 0.8086
# Epoch 51: val_loss improved from 0.54625 to 0.54151, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 51 history pickled and saved to file
# 65/65 [==============================] - 7s 108ms/step - loss: 0.4548 - accuracy: 0.8088 - val_loss: 0.5415 - val_accuracy: 0.7461
# Epoch 52/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4475 - accuracy: 0.8166
# Epoch 52: val_loss improved from 0.54151 to 0.53087, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 52 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.4475 - accuracy: 0.8166 - val_loss: 0.5309 - val_accuracy: 0.7461
# Epoch 53/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4448 - accuracy: 0.8203
# Epoch 53: val_loss did not improve from 0.53087
# Epoch 53 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.4443 - accuracy: 0.8205 - val_loss: 0.5331 - val_accuracy: 0.7539
# Epoch 54/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8224
# Epoch 54: val_loss did not improve from 0.53087
# Epoch 54 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4391 - accuracy: 0.8224 - val_loss: 0.5338 - val_accuracy: 0.7539
# Epoch 55/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8283
# Epoch 55: val_loss improved from 0.53087 to 0.52079, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 55 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.4365 - accuracy: 0.8283 - val_loss: 0.5208 - val_accuracy: 0.7539
# Epoch 56/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4306 - accuracy: 0.8271
# Epoch 56: val_loss improved from 0.52079 to 0.51840, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 56 history pickled and saved to file
# 65/65 [==============================] - 6s 95ms/step - loss: 0.4302 - accuracy: 0.8273 - val_loss: 0.5184 - val_accuracy: 0.7578
# Epoch 57/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4236 - accuracy: 0.8271
# Epoch 57: val_loss did not improve from 0.51840
# Epoch 57 history pickled and saved to file
# 65/65 [==============================] - 5s 80ms/step - loss: 0.4233 - accuracy: 0.8273 - val_loss: 0.5234 - val_accuracy: 0.7500
# Epoch 58/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4206 - accuracy: 0.8332
# Epoch 58: val_loss improved from 0.51840 to 0.50725, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 58 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.4206 - accuracy: 0.8332 - val_loss: 0.5072 - val_accuracy: 0.7617
# Epoch 59/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4185 - accuracy: 0.8301
# Epoch 59: val_loss did not improve from 0.50725
# Epoch 59 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.4181 - accuracy: 0.8302 - val_loss: 0.5333 - val_accuracy: 0.7695
# Epoch 60/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8341
# Epoch 60: val_loss did not improve from 0.50725
# Epoch 60 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4128 - accuracy: 0.8341 - val_loss: 0.5138 - val_accuracy: 0.7617
# Epoch 61/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4118 - accuracy: 0.8350
# Epoch 61: val_loss did not improve from 0.50725
# Epoch 61 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4136 - accuracy: 0.8341 - val_loss: 0.5097 - val_accuracy: 0.7578
# Epoch 62/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.8420
# Epoch 62: val_loss improved from 0.50725 to 0.50195, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 62 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.4065 - accuracy: 0.8420 - val_loss: 0.5019 - val_accuracy: 0.7656
# Epoch 63/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.4015 - accuracy: 0.8457
# Epoch 63: val_loss did not improve from 0.50195
# Epoch 63 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.4011 - accuracy: 0.8459 - val_loss: 0.5047 - val_accuracy: 0.7617
# Epoch 64/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3979 - accuracy: 0.8459
# Epoch 64: val_loss improved from 0.50195 to 0.48303, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 64 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.3979 - accuracy: 0.8459 - val_loss: 0.4830 - val_accuracy: 0.7695
# Epoch 65/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8468
# Epoch 65: val_loss did not improve from 0.48303
# Epoch 65 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3934 - accuracy: 0.8468 - val_loss: 0.4894 - val_accuracy: 0.7734
# Epoch 66/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3911 - accuracy: 0.8418
# Epoch 66: val_loss did not improve from 0.48303
# Epoch 66 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3908 - accuracy: 0.8420 - val_loss: 0.4852 - val_accuracy: 0.7734
# Epoch 67/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8468
# Epoch 67: val_loss did not improve from 0.48303
# Epoch 67 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3878 - accuracy: 0.8468 - val_loss: 0.4841 - val_accuracy: 0.7773
# Epoch 68/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3829 - accuracy: 0.8576
# Epoch 68: val_loss did not improve from 0.48303
# Epoch 68 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.3829 - accuracy: 0.8576 - val_loss: 0.4845 - val_accuracy: 0.7773
# Epoch 69/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.8537
# Epoch 69: val_loss improved from 0.48303 to 0.47073, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 69 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.3809 - accuracy: 0.8537 - val_loss: 0.4707 - val_accuracy: 0.7695
# Epoch 70/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8585
# Epoch 70: val_loss improved from 0.47073 to 0.46984, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 70 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.3783 - accuracy: 0.8585 - val_loss: 0.4698 - val_accuracy: 0.7734
# Epoch 71/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3738 - accuracy: 0.8564
# Epoch 71: val_loss improved from 0.46984 to 0.46111, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 71 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 0.3736 - accuracy: 0.8566 - val_loss: 0.4611 - val_accuracy: 0.7773
# Epoch 72/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3708 - accuracy: 0.8564
# Epoch 72: val_loss did not improve from 0.46111
# Epoch 72 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3709 - accuracy: 0.8566 - val_loss: 0.4621 - val_accuracy: 0.7852
# Epoch 73/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8595
# Epoch 73: val_loss did not improve from 0.46111
# Epoch 73 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3691 - accuracy: 0.8595 - val_loss: 0.4759 - val_accuracy: 0.7734
# Epoch 74/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8556
# Epoch 74: val_loss improved from 0.46111 to 0.46048, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 74 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.3677 - accuracy: 0.8556 - val_loss: 0.4605 - val_accuracy: 0.7852
# Epoch 75/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8615
# Epoch 75: val_loss did not improve from 0.46048
# Epoch 75 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3584 - accuracy: 0.8615 - val_loss: 0.4658 - val_accuracy: 0.7812
# Epoch 76/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8576
# Epoch 76: val_loss improved from 0.46048 to 0.45685, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 76 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.3577 - accuracy: 0.8576 - val_loss: 0.4569 - val_accuracy: 0.7852
# Epoch 77/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.8654
# Epoch 77: val_loss improved from 0.45685 to 0.44962, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 77 history pickled and saved to file
# 65/65 [==============================] - 7s 106ms/step - loss: 0.3554 - accuracy: 0.8654 - val_loss: 0.4496 - val_accuracy: 0.7891
# Epoch 78/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3547 - accuracy: 0.8672
# Epoch 78: val_loss did not improve from 0.44962
# Epoch 78 history pickled and saved to file
# 65/65 [==============================] - 5s 74ms/step - loss: 0.3545 - accuracy: 0.8673 - val_loss: 0.4497 - val_accuracy: 0.7852
# Epoch 79/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8673
# Epoch 79: val_loss did not improve from 0.44962
# Epoch 79 history pickled and saved to file
# 65/65 [==============================] - 6s 82ms/step - loss: 0.3499 - accuracy: 0.8673 - val_loss: 0.4526 - val_accuracy: 0.7852
# Epoch 80/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3476 - accuracy: 0.8662
# Epoch 80: val_loss did not improve from 0.44962
# Epoch 80 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3473 - accuracy: 0.8663 - val_loss: 0.4531 - val_accuracy: 0.7852
# Epoch 81/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.8712
# Epoch 81: val_loss improved from 0.44962 to 0.44186, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 81 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.3450 - accuracy: 0.8712 - val_loss: 0.4419 - val_accuracy: 0.7852
# Epoch 82/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8693
# Epoch 82: val_loss did not improve from 0.44186
# Epoch 82 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3426 - accuracy: 0.8693 - val_loss: 0.4427 - val_accuracy: 0.7930
# Epoch 83/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3407 - accuracy: 0.8750
# Epoch 83: val_loss improved from 0.44186 to 0.43922, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 83 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.3408 - accuracy: 0.8751 - val_loss: 0.4392 - val_accuracy: 0.7969
# Epoch 84/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3392 - accuracy: 0.8691
# Epoch 84: val_loss improved from 0.43922 to 0.43840, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 84 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.3389 - accuracy: 0.8693 - val_loss: 0.4384 - val_accuracy: 0.7969
# Epoch 85/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3340 - accuracy: 0.8721
# Epoch 85: val_loss improved from 0.43840 to 0.42885, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 85 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.3342 - accuracy: 0.8722 - val_loss: 0.4288 - val_accuracy: 0.7930
# Epoch 86/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3340 - accuracy: 0.8790
# Epoch 86: val_loss did not improve from 0.42885
# Epoch 86 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3340 - accuracy: 0.8790 - val_loss: 0.4454 - val_accuracy: 0.7852
# Epoch 87/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.8829
# Epoch 87: val_loss did not improve from 0.42885
# Epoch 87 history pickled and saved to file
# 65/65 [==============================] - 5s 75ms/step - loss: 0.3308 - accuracy: 0.8829 - val_loss: 0.4306 - val_accuracy: 0.7969
# Epoch 88/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3253 - accuracy: 0.8799
# Epoch 88: val_loss improved from 0.42885 to 0.42333, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 88 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.3253 - accuracy: 0.8800 - val_loss: 0.4233 - val_accuracy: 0.7969
# Epoch 89/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3260 - accuracy: 0.8751
# Epoch 89: val_loss improved from 0.42333 to 0.42112, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 89 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 0.3260 - accuracy: 0.8751 - val_loss: 0.4211 - val_accuracy: 0.8008
# Epoch 90/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3217 - accuracy: 0.8799
# Epoch 90: val_loss improved from 0.42112 to 0.41468, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 90 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.3213 - accuracy: 0.8800 - val_loss: 0.4147 - val_accuracy: 0.8008
# Epoch 91/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8829
# Epoch 91: val_loss did not improve from 0.41468
# Epoch 91 history pickled and saved to file
# 65/65 [==============================] - 5s 70ms/step - loss: 0.3193 - accuracy: 0.8829 - val_loss: 0.4153 - val_accuracy: 0.8008
# Epoch 92/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3193 - accuracy: 0.8760
# Epoch 92: val_loss did not improve from 0.41468
# Epoch 92 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.3190 - accuracy: 0.8761 - val_loss: 0.4317 - val_accuracy: 0.7969
# Epoch 93/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3152 - accuracy: 0.8818
# Epoch 93: val_loss did not improve from 0.41468
# Epoch 93 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3150 - accuracy: 0.8820 - val_loss: 0.4263 - val_accuracy: 0.8008
# Epoch 94/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3114 - accuracy: 0.8906
# Epoch 94: val_loss improved from 0.41468 to 0.41434, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 94 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.3112 - accuracy: 0.8907 - val_loss: 0.4143 - val_accuracy: 0.8008
# Epoch 95/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.8839
# Epoch 95: val_loss improved from 0.41434 to 0.41051, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 95 history pickled and saved to file
# 65/65 [==============================] - 7s 100ms/step - loss: 0.3115 - accuracy: 0.8839 - val_loss: 0.4105 - val_accuracy: 0.8047
# Epoch 96/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.8878
# Epoch 96: val_loss improved from 0.41051 to 0.40708, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 96 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.3068 - accuracy: 0.8878 - val_loss: 0.4071 - val_accuracy: 0.8047
# Epoch 97/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.3070 - accuracy: 0.8848
# Epoch 97: val_loss improved from 0.40708 to 0.40465, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 97 history pickled and saved to file
# 65/65 [==============================] - 7s 108ms/step - loss: 0.3070 - accuracy: 0.8849 - val_loss: 0.4047 - val_accuracy: 0.8086
# Epoch 98/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8917
# Epoch 98: val_loss did not improve from 0.40465
# Epoch 98 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.3039 - accuracy: 0.8917 - val_loss: 0.4091 - val_accuracy: 0.8125
# Epoch 99/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.8898
# Epoch 99: val_loss improved from 0.40465 to 0.39829, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 99 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.3050 - accuracy: 0.8898 - val_loss: 0.3983 - val_accuracy: 0.8086
# Epoch 100/300
# 65/65 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.8898
# Epoch 100: val_loss did not improve from 0.39829
# Epoch 100 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.3006 - accuracy: 0.8898 - val_loss: 0.3989 - val_accuracy: 0.8086
# Epoch 101/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2980 - accuracy: 0.8945
# Epoch 101: val_loss did not improve from 0.39829
# Epoch 101 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2980 - accuracy: 0.8946 - val_loss: 0.4144 - val_accuracy: 0.8125
# Epoch 102/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9024
# Epoch 102: val_loss did not improve from 0.39829
# Epoch 102 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2937 - accuracy: 0.9024 - val_loss: 0.4035 - val_accuracy: 0.8125
# Epoch 103/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.8955
# Epoch 103: val_loss improved from 0.39829 to 0.39631, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 103 history pickled and saved to file
# 65/65 [==============================] - 7s 105ms/step - loss: 0.2965 - accuracy: 0.8956 - val_loss: 0.3963 - val_accuracy: 0.8164
# Epoch 104/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2927 - accuracy: 0.8965
# Epoch 104: val_loss improved from 0.39631 to 0.38551, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 104 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.2926 - accuracy: 0.8966 - val_loss: 0.3855 - val_accuracy: 0.8125
# Epoch 105/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.8927
# Epoch 105: val_loss did not improve from 0.38551
# Epoch 105 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2907 - accuracy: 0.8927 - val_loss: 0.3857 - val_accuracy: 0.8164
# Epoch 106/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2878 - accuracy: 0.8955
# Epoch 106: val_loss did not improve from 0.38551
# Epoch 106 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2879 - accuracy: 0.8956 - val_loss: 0.3898 - val_accuracy: 0.8164
# Epoch 107/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2890 - accuracy: 0.8994
# Epoch 107: val_loss improved from 0.38551 to 0.38367, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 107 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.2887 - accuracy: 0.8995 - val_loss: 0.3837 - val_accuracy: 0.8203
# Epoch 108/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.9014
# Epoch 108: val_loss improved from 0.38367 to 0.37811, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 108 history pickled and saved to file
# 65/65 [==============================] - 7s 97ms/step - loss: 0.2844 - accuracy: 0.9005 - val_loss: 0.3781 - val_accuracy: 0.8242
# Epoch 109/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.8995
# Epoch 109: val_loss did not improve from 0.37811
# Epoch 109 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2867 - accuracy: 0.8995 - val_loss: 0.3932 - val_accuracy: 0.8203
# Epoch 110/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9034
# Epoch 110: val_loss did not improve from 0.37811
# Epoch 110 history pickled and saved to file
# 65/65 [==============================] - 6s 83ms/step - loss: 0.2832 - accuracy: 0.9034 - val_loss: 0.3940 - val_accuracy: 0.8242
# Epoch 111/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9044
# Epoch 111: val_loss did not improve from 0.37811
# Epoch 111 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.2781 - accuracy: 0.9044 - val_loss: 0.3782 - val_accuracy: 0.8242
# Epoch 112/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2774 - accuracy: 0.9034
# Epoch 112: val_loss did not improve from 0.37811
# Epoch 112 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2774 - accuracy: 0.9034 - val_loss: 0.3823 - val_accuracy: 0.8203
# Epoch 113/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9034
# Epoch 113: val_loss did not improve from 0.37811
# Epoch 113 history pickled and saved to file
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2781 - accuracy: 0.9034 - val_loss: 0.3878 - val_accuracy: 0.8242
# Epoch 114/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.9063
# Epoch 114: val_loss did not improve from 0.37811
# Epoch 114 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2747 - accuracy: 0.9063 - val_loss: 0.3998 - val_accuracy: 0.8125
# Epoch 115/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2726 - accuracy: 0.9072
# Epoch 115: val_loss improved from 0.37811 to 0.36965, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 115 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.2727 - accuracy: 0.9073 - val_loss: 0.3696 - val_accuracy: 0.8359
# Epoch 116/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2708 - accuracy: 0.9072
# Epoch 116: val_loss did not improve from 0.36965
# Epoch 116 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2707 - accuracy: 0.9073 - val_loss: 0.3728 - val_accuracy: 0.8320
# Epoch 117/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2700 - accuracy: 0.9092
# Epoch 117: val_loss did not improve from 0.36965
# Epoch 117 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.2697 - accuracy: 0.9093 - val_loss: 0.3747 - val_accuracy: 0.8242
# Epoch 118/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2706 - accuracy: 0.9092
# Epoch 118: val_loss did not improve from 0.36965
# Epoch 118 history pickled and saved to file
# 65/65 [==============================] - 5s 81ms/step - loss: 0.2704 - accuracy: 0.9093 - val_loss: 0.3884 - val_accuracy: 0.8164
# Epoch 119/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2675 - accuracy: 0.9015
# Epoch 119: val_loss did not improve from 0.36965
# Epoch 119 history pickled and saved to file
# 65/65 [==============================] - 5s 75ms/step - loss: 0.2675 - accuracy: 0.9015 - val_loss: 0.3768 - val_accuracy: 0.8281
# Epoch 120/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2661 - accuracy: 0.9082
# Epoch 120: val_loss did not improve from 0.36965
# Epoch 120 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2658 - accuracy: 0.9083 - val_loss: 0.3697 - val_accuracy: 0.8281
# Epoch 121/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.9102
# Epoch 121: val_loss did not improve from 0.36965
# Epoch 121 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2631 - accuracy: 0.9102 - val_loss: 0.3757 - val_accuracy: 0.8281
# Epoch 122/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9141
# Epoch 122: val_loss improved from 0.36965 to 0.36347, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 122 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.2627 - accuracy: 0.9141 - val_loss: 0.3635 - val_accuracy: 0.8398
# Epoch 123/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2604 - accuracy: 0.9102
# Epoch 123: val_loss did not improve from 0.36347
# Epoch 123 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.2601 - accuracy: 0.9102 - val_loss: 0.3689 - val_accuracy: 0.8320
# Epoch 124/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.9102
# Epoch 124: val_loss did not improve from 0.36347
# Epoch 124 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2583 - accuracy: 0.9102 - val_loss: 0.3682 - val_accuracy: 0.8320
# Epoch 125/300
# 65/65 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.9083
# Epoch 125: val_loss improved from 0.36347 to 0.36150, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 125 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.2571 - accuracy: 0.9083 - val_loss: 0.3615 - val_accuracy: 0.8359
# Epoch 126/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2557 - accuracy: 0.9131
# Epoch 126: val_loss did not improve from 0.36150
# Epoch 126 history pickled and saved to file
# 65/65 [==============================] - 5s 81ms/step - loss: 0.2554 - accuracy: 0.9132 - val_loss: 0.3664 - val_accuracy: 0.8320
# Epoch 127/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9131
# ...
# Epoch 254: val_loss did not improve from 0.27063
# Epoch 254 history pickled and saved to file
# 65/65 [==============================] - 5s 75ms/step - loss: 0.1484 - accuracy: 0.9620 - val_loss: 0.2823 - val_accuracy: 0.8906
# Epoch 255/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9648
# Epoch 255: val_loss improved from 0.27063 to 0.26964, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 255 history pickled and saved to file
# 65/65 [==============================] - 7s 98ms/step - loss: 0.1464 - accuracy: 0.9649 - val_loss: 0.2696 - val_accuracy: 0.8828
# Epoch 256/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9659
# Epoch 256: val_loss did not improve from 0.26964
# Epoch 256 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1478 - accuracy: 0.9659 - val_loss: 0.2750 - val_accuracy: 0.8906
# Epoch 257/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9639
# Epoch 257: val_loss improved from 0.26964 to 0.26849, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 257 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.1457 - accuracy: 0.9639 - val_loss: 0.2685 - val_accuracy: 0.8867
# Epoch 258/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9659
# Epoch 258: val_loss did not improve from 0.26849
# Epoch 258 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1454 - accuracy: 0.9659 - val_loss: 0.2752 - val_accuracy: 0.8906
# Epoch 259/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9668
# Epoch 259: val_loss did not improve from 0.26849
# Epoch 259 history pickled and saved to file
# 65/65 [==============================] - 6s 83ms/step - loss: 0.1442 - accuracy: 0.9668 - val_loss: 0.2694 - val_accuracy: 0.8867
# Epoch 260/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9639
# Epoch 260: val_loss improved from 0.26849 to 0.26812, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 260 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.1439 - accuracy: 0.9639 - val_loss: 0.2681 - val_accuracy: 0.8906
# Epoch 261/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9619
# Epoch 261: val_loss did not improve from 0.26812
# Epoch 261 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1453 - accuracy: 0.9620 - val_loss: 0.2791 - val_accuracy: 0.8906
# Epoch 262/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9668
# Epoch 262: val_loss did not improve from 0.26812
# Epoch 262 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1439 - accuracy: 0.9668 - val_loss: 0.2719 - val_accuracy: 0.8906
# Epoch 263/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9659
# Epoch 263: val_loss did not improve from 0.26812
# Epoch 263 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1424 - accuracy: 0.9659 - val_loss: 0.2698 - val_accuracy: 0.8906
# Epoch 264/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1422 - accuracy: 0.9648
# Epoch 264: val_loss did not improve from 0.26812
# Epoch 264 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1421 - accuracy: 0.9649 - val_loss: 0.2705 - val_accuracy: 0.8906
# Epoch 265/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1429 - accuracy: 0.9668
# Epoch 265: val_loss did not improve from 0.26812
# Epoch 265 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1428 - accuracy: 0.9668 - val_loss: 0.2748 - val_accuracy: 0.8906
# Epoch 266/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1410 - accuracy: 0.9688
# Epoch 266: val_loss improved from 0.26812 to 0.26648, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 266 history pickled and saved to file
# 65/65 [==============================] - 6s 96ms/step - loss: 0.1409 - accuracy: 0.9688 - val_loss: 0.2665 - val_accuracy: 0.8945
# Epoch 267/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9678
# Epoch 267: val_loss did not improve from 0.26648
# Epoch 267 history pickled and saved to file
# 65/65 [==============================] - 5s 80ms/step - loss: 0.1404 - accuracy: 0.9678 - val_loss: 0.2684 - val_accuracy: 0.8906
# Epoch 268/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9668
# Epoch 268: val_loss did not improve from 0.26648
# Epoch 268 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1408 - accuracy: 0.9668 - val_loss: 0.2763 - val_accuracy: 0.8906
# Epoch 269/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1404 - accuracy: 0.9658
# Epoch 269: val_loss did not improve from 0.26648
# Epoch 269 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1403 - accuracy: 0.9659 - val_loss: 0.2679 - val_accuracy: 0.8945
# Epoch 270/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9678
# Epoch 270: val_loss improved from 0.26648 to 0.26429, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 270 history pickled and saved to file
# 65/65 [==============================] - 7s 99ms/step - loss: 0.1389 - accuracy: 0.9678 - val_loss: 0.2643 - val_accuracy: 0.8906
# Epoch 271/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9668
# Epoch 271: val_loss did not improve from 0.26429
# Epoch 271 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1388 - accuracy: 0.9668 - val_loss: 0.2657 - val_accuracy: 0.8945
# Epoch 272/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9659
# Epoch 272: val_loss did not improve from 0.26429
# Epoch 272 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1397 - accuracy: 0.9659 - val_loss: 0.2658 - val_accuracy: 0.8984
# Epoch 273/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1385 - accuracy: 0.9678
# Epoch 273: val_loss did not improve from 0.26429
# Epoch 273 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1387 - accuracy: 0.9678 - val_loss: 0.2749 - val_accuracy: 0.8984
# Epoch 274/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9707
# Epoch 274: val_loss improved from 0.26429 to 0.26402, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 274 history pickled and saved to file
# 65/65 [==============================] - 6s 97ms/step - loss: 0.1372 - accuracy: 0.9707 - val_loss: 0.2640 - val_accuracy: 0.8945
# Epoch 275/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9698
# Epoch 275: val_loss did not improve from 0.26402
# Epoch 275 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1375 - accuracy: 0.9698 - val_loss: 0.2663 - val_accuracy: 0.8945
# Epoch 276/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9678
# Epoch 276: val_loss did not improve from 0.26402
# Epoch 276 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1377 - accuracy: 0.9678 - val_loss: 0.2707 - val_accuracy: 0.8984
# Epoch 277/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1360 - accuracy: 0.9717
# Epoch 277: val_loss improved from 0.26402 to 0.26347, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 277 history pickled and saved to file
# 65/65 [==============================] - 7s 101ms/step - loss: 0.1359 - accuracy: 0.9717 - val_loss: 0.2635 - val_accuracy: 0.8945
# Epoch 278/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9707
# Epoch 278: val_loss improved from 0.26347 to 0.26153, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 278 history pickled and saved to file
# 65/65 [==============================] - 7s 100ms/step - loss: 0.1353 - accuracy: 0.9707 - val_loss: 0.2615 - val_accuracy: 0.8906
# Epoch 279/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9717
# Epoch 279: val_loss did not improve from 0.26153
# Epoch 279 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1355 - accuracy: 0.9717 - val_loss: 0.2671 - val_accuracy: 0.8945
# Epoch 280/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9717
# Epoch 280: val_loss did not improve from 0.26153
# Epoch 280 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1354 - accuracy: 0.9717 - val_loss: 0.2634 - val_accuracy: 0.8906
# Epoch 281/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9698
# Epoch 281: val_loss did not improve from 0.26153
# Epoch 281 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1347 - accuracy: 0.9698 - val_loss: 0.2628 - val_accuracy: 0.8945
# Epoch 282/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9707
# Epoch 282: val_loss improved from 0.26153 to 0.25910, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 282 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.1331 - accuracy: 0.9707 - val_loss: 0.2591 - val_accuracy: 0.8906
# Epoch 283/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9668
# Epoch 283: val_loss did not improve from 0.25910
# Epoch 283 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1379 - accuracy: 0.9668 - val_loss: 0.2689 - val_accuracy: 0.8984
# Epoch 284/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9707
# Epoch 284: val_loss did not improve from 0.25910
# Epoch 284 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1328 - accuracy: 0.9707 - val_loss: 0.2631 - val_accuracy: 0.8984
# Epoch 285/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9717
# Epoch 285: val_loss did not improve from 0.25910
# Epoch 285 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1329 - accuracy: 0.9717 - val_loss: 0.2622 - val_accuracy: 0.8984
# Epoch 286/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9698
# Epoch 286: val_loss did not improve from 0.25910
# Epoch 286 history pickled and saved to file
# 65/65 [==============================] - 5s 74ms/step - loss: 0.1334 - accuracy: 0.9698 - val_loss: 0.2635 - val_accuracy: 0.8945
# Epoch 287/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1324 - accuracy: 0.9717
# Epoch 287: val_loss did not improve from 0.25910
# Epoch 287 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1325 - accuracy: 0.9717 - val_loss: 0.2677 - val_accuracy: 0.8984
# Epoch 288/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9727
# Epoch 288: val_loss did not improve from 0.25910
# Epoch 288 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1336 - accuracy: 0.9727 - val_loss: 0.2639 - val_accuracy: 0.8945
# Epoch 289/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1316 - accuracy: 0.9707
# Epoch 289: val_loss improved from 0.25910 to 0.25632, saving model to /content/drive/MyDrive/lion_no_lion/model_weights_Adis_XCeption_512_512.keras
# Epoch 289 history pickled and saved to file
# 65/65 [==============================] - 7s 104ms/step - loss: 0.1315 - accuracy: 0.9707 - val_loss: 0.2563 - val_accuracy: 0.8906
# Epoch 290/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9707
# Epoch 290: val_loss did not improve from 0.25632
# Epoch 290 history pickled and saved to file
# 65/65 [==============================] - 5s 71ms/step - loss: 0.1321 - accuracy: 0.9707 - val_loss: 0.2730 - val_accuracy: 0.8906
# Epoch 291/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9746
# Epoch 291: val_loss did not improve from 0.25632
# Epoch 291 history pickled and saved to file
# 65/65 [==============================] - 5s 74ms/step - loss: 0.1307 - accuracy: 0.9746 - val_loss: 0.2652 - val_accuracy: 0.8984
# Epoch 292/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9717
# Epoch 292: val_loss did not improve from 0.25632
# Epoch 292 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1303 - accuracy: 0.9717 - val_loss: 0.2648 - val_accuracy: 0.8984
# Epoch 293/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1306 - accuracy: 0.9697
# Epoch 293: val_loss did not improve from 0.25632
# Epoch 293 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1305 - accuracy: 0.9698 - val_loss: 0.2579 - val_accuracy: 0.8906
# Epoch 294/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9707
# Epoch 294: val_loss did not improve from 0.25632
# Epoch 294 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1288 - accuracy: 0.9707 - val_loss: 0.2644 - val_accuracy: 0.8984
# Epoch 295/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9727
# Epoch 295: val_loss did not improve from 0.25632
# Epoch 295 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1289 - accuracy: 0.9727 - val_loss: 0.2718 - val_accuracy: 0.8867
# Epoch 296/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9707
# Epoch 296: val_loss did not improve from 0.25632
# Epoch 296 history pickled and saved to file
# 65/65 [==============================] - 5s 74ms/step - loss: 0.1286 - accuracy: 0.9707 - val_loss: 0.2611 - val_accuracy: 0.8945
# Epoch 297/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9717
# Epoch 297: val_loss did not improve from 0.25632
# Epoch 297 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1279 - accuracy: 0.9717 - val_loss: 0.2580 - val_accuracy: 0.8945
# Epoch 298/300
# 65/65 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9707
# Epoch 298: val_loss did not improve from 0.25632
# Epoch 298 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1303 - accuracy: 0.9707 - val_loss: 0.2714 - val_accuracy: 0.8906
# Epoch 299/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.9736
# Epoch 299: val_loss did not improve from 0.25632
# Epoch 299 history pickled and saved to file
# 65/65 [==============================] - 5s 72ms/step - loss: 0.1272 - accuracy: 0.9737 - val_loss: 0.2682 - val_accuracy: 0.8984
# Epoch 300/300
# 64/65 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9756
# Epoch 300: val_loss did not improve from 0.25632
# Epoch 300 history pickled and saved to file
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1265 - accuracy: 0.9756 - val_loss: 0.2584 - val_accuracy: 0.8945
# 2024-05-31 22:01:33.372870
# This run took 1874.350461 seconds

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))
plt.subplot(1, 2, 1)
plt.plot(full_history.history['accuracy'], label='Training Accuracy')
plt.plot(full_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(full_history.history['loss'], label='Training Loss')
plt.plot(full_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 1.0])
plt.title('Training and Validation Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

images, labels = next(iter(validation_dataset))

# Predict the labels for the images
predictions = model.predict(images)

# Plot the images and their predicted labels
plt.figure(figsize=(18, 18))
for i in range(9):
  plt.subplot(3, 3, i + 1)
  plt.imshow(images[i].numpy().astype("uint8"))
  plt.title(f"Predicted: {predictions[i][0]:.2f} ({'lion' if predictions[i][0] < 0.5 else 'no lion'}), Actual: {labels[i]} ({'lion' if labels[i] == 0 else 'no lion'})")
  plt.axis('off')

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

# classification_directory = '/content/drive/MyDrive/lion_no_lion/stable/angle 1'
classification_directory = '/content/drive/MyDrive/lion_no_lion/stable/angle 2/Lion'
# classification_directory = '/content/drive/MyDrive/lion_no_lion/cougar'
# classification_directory = '/content/drive/MyDrive/lion_no_lion/lion'
# classification_directory = '/content/drive/MyDrive/lion_no_lion/nocougar'
classification_image_files = glob.glob(os.path.join(classification_directory,"*JPG"))
classifications = []
for image_file in classification_image_files:
    image_data = tf.keras.utils.load_img(image_file, target_size=image_dimensions)
    image_data = tf.keras.utils.img_to_array(image_data)
    prediction = model.predict(np.expand_dims(image_data, 0))
    classifications.append({})
    classifications[-1]['path'] = image_file
    classifications[-1]['image'] = image_data
    classifications[-1]['prediction'] = prediction[0][0]

    plt.figure(figsize=(8, 8))
    plt.imshow(np.array(classifications[-1]['image'].astype("uint8")))
    plt.title(f'{(1-classifications[-1]["prediction"])*100:.2f}% lion - {classifications[-1]["prediction"]*100:.2f}% no_lion')
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
